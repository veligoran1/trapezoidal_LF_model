# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import test_theta_hidden_dim_single_pde
from utils.plot_utils import plot_theta_hidden_dim_comparison

# %% [markdown]
# ## Testing different NN size

# %%
hidden_dims = [1, 2, 3, 4, 8]

# %% [markdown]
# ### Heat Equation

# %%
results, domain, title = test_theta_hidden_dim_single_pde(
        pde_type='heat',
        hidden_dims=hidden_dims,
        n_runs=5,
        epochs=140,
        verbose=True
    )
    
plot_theta_hidden_dim_comparison(results, 'heat')
# Out:
# ...
# THETA HIDDEN DIM TESTING: Heat Equation
# Hidden dims: [1, 2, 3, 4, 8]
# Parameter counts: [7, 13, 19, 25, 49]
# Runs per value: 5
# Model params: n_steps=4, n_iterations=2, lr=0.005
# ...
#
#
# ...
# Testing: theta_hidden_dim=1 (7 params)
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 7
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ...
#
#    Epoch    0: Loss=5.49e-03, PDE=5.49e-03, θ=0.399±0.000
#    Epoch   14: Loss=2.19e-03, PDE=2.19e-03, θ=0.388±0.001
#    Epoch   28: Loss=5.58e-03, PDE=5.58e-03, θ=0.386±0.001
#    Epoch   42: Loss=5.20e-03, PDE=5.20e-03, θ=0.385±0.002
#    Epoch   56: Loss=3.93e-03, PDE=3.93e-03, θ=0.385±0.003
#    Epoch   70: Loss=4.77e-03, PDE=4.77e-03, θ=0.382±0.004
#    Epoch   84: Loss=4.15e-03, PDE=4.15e-03, θ=0.377±0.006
#    Epoch   98: Loss=4.07e-03, PDE=4.07e-03, θ=0.378±0.009
#    Epoch  112: Loss=3.54e-03, PDE=3.54e-03, θ=0.373±0.012
#    Epoch  126: Loss=3.17e-03, PDE=3.17e-03, θ=0.362±0.018
# ...

# %% [markdown]
# ### Wave Equation

# %%
results, domain, title = test_theta_hidden_dim_single_pde(
        pde_type='wave',
        hidden_dims=hidden_dims,
        n_runs=5,
        epochs=120,
        verbose=True
    )
    
plot_theta_hidden_dim_comparison(results, 'wave')
# Out:
# ...
# THETA HIDDEN DIM TESTING: Wave Equation
# Hidden dims: [1, 2, 3, 4, 8]
# Parameter counts: [7, 13, 19, 25, 49]
# Runs per value: 5
# Model params: n_steps=3, n_iterations=3, lr=0.001
# ...
#
#
# ...
# Testing: theta_hidden_dim=1 (7 params)
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 7
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ...
#
#    Epoch    0: Loss=2.28e+00, PDE=2.28e+00, θ=0.500±0.000
#    Epoch   12: Loss=1.81e+00, PDE=1.81e+00, θ=0.496±0.000
#    Epoch   24: Loss=1.56e+00, PDE=1.56e+00, θ=0.492±0.001
#    Epoch   36: Loss=1.22e+00, PDE=1.22e+00, θ=0.488±0.001
#    Epoch   48: Loss=1.04e+00, PDE=1.04e+00, θ=0.483±0.002
#    Epoch   60: Loss=8.58e-01, PDE=8.58e-01, θ=0.479±0.003
#    Epoch   72: Loss=1.01e+00, PDE=1.01e+00, θ=0.474±0.003
#    Epoch   84: Loss=1.46e+00, PDE=1.46e+00, θ=0.468±0.004
#    Epoch   96: Loss=3.50e-01, PDE=3.50e-01, θ=0.463±0.005
#    Epoch  108: Loss=7.05e-01, PDE=7.05e-01, θ=0.457±0.005
# ...

# %% [markdown]
# ### Burgers Equation

# %%
results, domain, title = test_theta_hidden_dim_single_pde(
        pde_type='burgers',
        hidden_dims=hidden_dims,
        n_runs=5,
        epochs=200,
        verbose=True
    )
    
plot_theta_hidden_dim_comparison(results, 'burgers')
# Out:
# ...
# THETA HIDDEN DIM TESTING: Burgers Equation
# Hidden dims: [1, 2, 3, 4, 8]
# Parameter counts: [7, 13, 19, 25, 49]
# Runs per value: 5
# Model params: n_steps=2, n_iterations=2, lr=0.0005
# ...
#
#
# ...
# Testing: theta_hidden_dim=1 (7 params)
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 7
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.2
# ...
#
#    Epoch    0: Loss=6.09e+00, PDE=6.09e+00, θ=0.200±0.000
#    Epoch   20: Loss=2.42e+00, PDE=2.42e+00, θ=0.199±0.000
#    Epoch   40: Loss=1.77e+00, PDE=1.77e+00, θ=0.199±0.000
#    Epoch   60: Loss=5.75e-01, PDE=5.75e-01, θ=0.198±0.001
#    Epoch   80: Loss=3.08e-01, PDE=3.08e-01, θ=0.197±0.001
#    Epoch  100: Loss=6.33e-01, PDE=6.33e-01, θ=0.197±0.001
#    Epoch  120: Loss=1.77e+00, PDE=1.77e+00, θ=0.197±0.001
#    Epoch  140: Loss=3.27e+00, PDE=3.27e+00, θ=0.196±0.001
#    Epoch  160: Loss=2.31e+00, PDE=2.31e+00, θ=0.196±0.002
# ...

# %% [markdown]
# ### Reaction-Diffusion Equation

# %%
results, domain, title = test_theta_hidden_dim_single_pde(
        pde_type='reaction_diffusion',
        hidden_dims=hidden_dims,
        n_runs=5,
        epochs=200,
        verbose=True
    )
    
plot_theta_hidden_dim_comparison(results, 'reaction_diffusion')
# Out:
# ...
# THETA HIDDEN DIM TESTING: Reaction-Diffusion
# Hidden dims: [1, 2, 3, 4, 8]
# Parameter counts: [7, 13, 19, 25, 49]
# Runs per value: 5
# Model params: n_steps=2, n_iterations=2, lr=0.005
# ...
#
#
# ...
# Testing: theta_hidden_dim=1 (7 params)
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 7
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ...
#
#    Epoch    0: Loss=1.64e-02, PDE=1.64e-02, θ=0.299±0.000
#    Epoch   20: Loss=9.95e-03, PDE=9.95e-03, θ=0.285±0.003
#    Epoch   40: Loss=6.69e-03, PDE=6.69e-03, θ=0.266±0.007
#    Epoch   60: Loss=9.80e-03, PDE=9.80e-03, θ=0.248±0.009
#    Epoch   80: Loss=5.49e-05, PDE=5.49e-05, θ=0.223±0.009
#    Epoch  100: Loss=7.44e-05, PDE=7.44e-05, θ=0.208±0.009
#    Epoch  120: Loss=3.22e-04, PDE=3.22e-04, θ=0.202±0.011
#    Epoch  140: Loss=5.80e-04, PDE=5.80e-04, θ=0.188±0.009
#    Epoch  160: Loss=2.46e-03, PDE=2.46e-03, θ=0.185±0.012
# ...
