# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import numpy as np
import matplotlib.pyplot as plt

from utils.benchmark_utils import test_heat, test_wave, test_burgers, test_reaction_diffusion, run_all_tests

# %%
test_heat(n_steps = 4, n_iterations =2, lr = 0.005, epochs = 200)
# Out:
# ...
# TEST: Heat Equation
# ...
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ...
#
#    Epoch    0: Loss=4.83e-03, PDE=4.83e-03, θ=0.403±0.006
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_heat(n_steps = 4, n_iterations =2, lr = 0.005, epochs = 200)
#
# File ~/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/benchmark_utils.py:39, in test_heat(n_steps, n_iterations, lr, epochs)
#      36 domain = DOMAINS['heat']
#      37 exact_sol = get_exact_solution_parametric('heat')
# ---> 39 history = train_universal(model, domain, epochs=epochs, n_collocation=30, lr=lr)
#      40 results = evaluate(model, domain, exact_solution=exact_sol)
#      42 if isinstance(results['theta_statistics'], dict):
#
# ...

# %%
test_wave(n_steps = 3, n_iterations=3, lr = 0.001, epochs = 200)
# Out:
# ...
# TEST: Wave Equation
# ...
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ...
#
#    Epoch    0: Loss=1.24e+00, PDE=1.24e+00, θ=0.500±0.000
#    Epoch   20: Loss=1.57e+00, PDE=1.57e+00, θ=0.492±0.000
#    Epoch   40: Loss=1.19e+00, PDE=1.19e+00, θ=0.483±0.001
#    Epoch   60: Loss=1.27e+00, PDE=1.27e+00, θ=0.473±0.001
#    Epoch   80: Loss=4.47e-01, PDE=4.47e-01, θ=0.460±0.000
#    Epoch  100: Loss=3.04e-01, PDE=3.04e-01, θ=0.447±0.001
#    Epoch  120: Loss=1.66e-01, PDE=1.66e-01, θ=0.432±0.002
#    Epoch  140: Loss=4.69e-02, PDE=4.69e-02, θ=0.418±0.003
#    Epoch  160: Loss=5.73e-02, PDE=5.73e-02, θ=0.415±0.003
#    Epoch  180: Loss=4.94e-02, PDE=4.94e-02, θ=0.415±0.003
#
# Results:
#   θ (mean): 0.4176 ± 0.0030
#   θ (range): [0.4118, 0.4238]
#   PDE residual: 6.03e-02
#   Mean error: 1.51e-02
#   Max error: 3.02e-02
# ...
# Final Parameters:
#   n_steps              = 3.000000
# ...

# %%
test_reaction_diffusion(n_steps=2, n_iterations=2, lr=0.001, epochs = 10)
# Out:
# ...
# TEST: Reaction-Diffusion Equation
# ...
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.35
# ...
#
#    Epoch    0: Loss=5.26e-02, PDE=5.26e-02, θ=0.348±0.005
#    Epoch    1: Loss=8.95e-02, PDE=8.95e-02, θ=0.347±0.005
#    Epoch    2: Loss=2.23e-02, PDE=2.23e-02, θ=0.348±0.005
#    Epoch    3: Loss=6.78e-03, PDE=6.78e-03, θ=0.346±0.004
#    Epoch    4: Loss=2.78e-03, PDE=2.78e-03, θ=0.345±0.004
#    Epoch    5: Loss=5.28e-02, PDE=5.28e-02, θ=0.345±0.005
#    Epoch    6: Loss=9.85e-02, PDE=9.85e-02, θ=0.345±0.005
#    Epoch    7: Loss=1.51e-03, PDE=1.51e-03, θ=0.345±0.004
#    Epoch    8: Loss=3.28e-03, PDE=3.28e-03, θ=0.346±0.005
#    Epoch    9: Loss=1.40e-01, PDE=1.40e-01, θ=0.344±0.005
#
# Results:
#   θ (mean): 0.3439 ± 0.0049
#   θ (range): [0.3360, 0.3556]
#   PDE residual: 9.85e-04
#   RMSE error: 9.12e-02
#   L2RE error: 1.36e-01
# ...
# Final Parameters:
# ...

# %%
test_burgers(n_steps = 2, n_iterations =2, lr = 0.0005, epochs = 200)
# Out:
# ...
# TEST: Burgers Equation
# ...
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ...
#
#    Epoch    0: Loss=2.11e+00, PDE=2.11e+00, θ=0.300±0.000
#    Epoch   20: Loss=1.16e+01, PDE=1.16e+01, θ=0.294±0.001
#    Epoch   40: Loss=7.55e+00, PDE=7.55e+00, θ=0.289±0.001
#    Epoch   60: Loss=2.47e-01, PDE=2.47e-01, θ=0.285±0.001
#    Epoch   80: Loss=2.21e-01, PDE=2.21e-01, θ=0.281±0.001
#    Epoch  100: Loss=4.86e+00, PDE=4.86e+00, θ=0.277±0.002
#    Epoch  120: Loss=5.70e+00, PDE=5.70e+00, θ=0.272±0.002
#    Epoch  140: Loss=4.82e-01, PDE=4.82e-01, θ=0.267±0.002
#    Epoch  160: Loss=2.93e+00, PDE=2.93e+00, θ=0.264±0.002
#    Epoch  180: Loss=2.30e+00, PDE=2.30e+00, θ=0.258±0.003
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
# ...
