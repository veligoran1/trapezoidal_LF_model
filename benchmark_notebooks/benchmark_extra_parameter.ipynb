# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import test_input_features_single_pde
from utils.plot_utils import plot_input_features_comparison
from utils.config import FEATURE_SETS

# %% [markdown]
# ## Testing Different Input Feature Sets

# %% [markdown]
# ### Heat Equation

# %%
results, domain, title = test_input_features_single_pde(
        pde_type='heat',
        n_runs=5,
        epochs=120,
        verbose=True
    )
    
plot_input_features_comparison(results, pde_type='heat', feature_sets={
            'no_grad': FEATURE_SETS['no_grad'],
            'default': FEATURE_SETS['default'],
            'with_y': FEATURE_SETS['with_y'],
            'with_t_norm': FEATURE_SETS['with_t_norm'],
            'with_y_abs':FEATURE_SETS['with_y'],
            'with_laplacian':FEATURE_SETS['with_laplacian'],
            'full': FEATURE_SETS['full']
        })
# Out:
# ...
# INPUT FEATURES TESTING: Heat Equation
# Feature sets: ['no_grad', 'default', 'with_y', 'with_t_norm', 'with_y_abs', 'with_laplacian', 'full']
# Runs per set: 5
# Model params: n_steps=4, n_iterations=2, lr=0.005
# ...
#
#
# ...
# Testing: no_grad
# Features (3): ['x', 't', 't_next']
# Theta params: 11
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# LF-PINN Input Features Test
# PDE: heat | Steps: 4 | Theta params: 11
# Input features (3): ['x', 't', 't_next']
# Initial theta: 0.4
# ...
#
#    Epoch    0: Loss=6.77e-03, PDE=6.77e-03, θ=0.398±0.000
#    Epoch   12: Loss=3.79e-03, PDE=3.79e-03, θ=0.385±0.002
#    Epoch   24: Loss=4.09e-03, PDE=4.09e-03, θ=0.383±0.004
#    Epoch   36: Loss=2.94e-03, PDE=2.94e-03, θ=0.384±0.006
#    Epoch   48: Loss=1.84e-03, PDE=1.84e-03, θ=0.383±0.008
#    Epoch   60: Loss=3.36e-03, PDE=3.36e-03, θ=0.379±0.011
#    Epoch   72: Loss=2.71e-03, PDE=2.71e-03, θ=0.377±0.014
#    Epoch   84: Loss=2.39e-03, PDE=2.39e-03, θ=0.366±0.020
#    Epoch   96: Loss=3.05e-03, PDE=3.05e-03, θ=0.360±0.024
# ...

# %% [markdown]
# ### Burgers Equation

# %%
results, domain, title = test_input_features_single_pde(
        pde_type='burgers',
        n_runs=5,
        epochs=200,
        verbose=True
    )
    
plot_input_features_comparison(results, pde_type='burgers', feature_sets={
            'no_grad': FEATURE_SETS['no_grad'],
            'default': FEATURE_SETS['default'],
            'with_y': FEATURE_SETS['with_y'],
            'with_t_norm': FEATURE_SETS['with_t_norm'],
            'with_y_abs':FEATURE_SETS['with_y'],
            'with_laplacian':FEATURE_SETS['with_laplacian'],
            'full': FEATURE_SETS['full']
        })
# Out:
# ...
# INPUT FEATURES TESTING: Burgers Equation
# Feature sets: ['no_grad', 'default', 'with_y', 'with_t_norm', 'with_y_abs', 'with_laplacian', 'full']
# Runs per set: 5
# Model params: n_steps=2, n_iterations=2, lr=0.0005
# ...
#
#
# ...
# Testing: no_grad
# Features (3): ['x', 't', 't_next']
# Theta params: 11
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# LF-PINN Input Features Test
# PDE: burgers | Steps: 2 | Theta params: 11
# Input features (3): ['x', 't', 't_next']
# Initial theta: 0.2
# ...
#
#    Epoch    0: Loss=6.08e+00, PDE=6.08e+00, θ=0.200±0.000
#    Epoch   20: Loss=2.19e-01, PDE=2.19e-01, θ=0.199±0.000
#    Epoch   40: Loss=3.06e-01, PDE=3.06e-01, θ=0.199±0.000
#    Epoch   60: Loss=3.44e+00, PDE=3.44e+00, θ=0.198±0.000
#    Epoch   80: Loss=2.07e+00, PDE=2.07e+00, θ=0.197±0.000
#    Epoch  100: Loss=5.04e+00, PDE=5.04e+00, θ=0.195±0.000
#    Epoch  120: Loss=8.59e-01, PDE=8.59e-01, θ=0.193±0.000
#    Epoch  140: Loss=5.12e+00, PDE=5.12e+00, θ=0.193±0.000
# ...

# %% [markdown]
# ### Reaction-Diffusion Equation

# %%
results, domain, title = test_input_features_single_pde(
        pde_type='reaction_diffusion',
        n_runs=5,
        epochs=200,
        verbose=True
    )
    
plot_input_features_comparison(results, pde_type='reaction_diffusion', feature_sets={
            'no_grad': FEATURE_SETS['no_grad'],
            'default': FEATURE_SETS['default'],
            'with_y': FEATURE_SETS['with_y'],
            'with_t_norm': FEATURE_SETS['with_t_norm'],
            'with_y_abs':FEATURE_SETS['with_y'],
            'with_laplacian':FEATURE_SETS['with_laplacian'],
            'full': FEATURE_SETS['full']
        })
# Out:
# ...
# INPUT FEATURES TESTING: Reaction-Diffusion
# Feature sets: ['no_grad', 'default', 'with_y', 'with_t_norm', 'with_y_abs', 'with_laplacian', 'full']
# Runs per set: 5
# Model params: n_steps=2, n_iterations=2, lr=0.005
# ...
#
#
# ...
# Testing: no_grad
# Features (3): ['x', 't', 't_next']
# Theta params: 11
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# LF-PINN Input Features Test
# PDE: reaction_diffusion | Steps: 2 | Theta params: 11
# Input features (3): ['x', 't', 't_next']
# Initial theta: 0.3
# ...
#
#    Epoch    0: Loss=1.64e-02, PDE=1.64e-02, θ=0.298±0.000
#    Epoch   20: Loss=3.73e-04, PDE=3.73e-04, θ=0.280±0.001
#    Epoch   40: Loss=6.24e-04, PDE=6.24e-04, θ=0.260±0.002
#    Epoch   60: Loss=3.48e-03, PDE=3.48e-03, θ=0.234±0.002
#    Epoch   80: Loss=1.21e-03, PDE=1.21e-03, θ=0.216±0.002
#    Epoch  100: Loss=8.04e-04, PDE=8.04e-04, θ=0.191±0.004
#    Epoch  120: Loss=1.41e-04, PDE=1.41e-04, θ=0.181±0.004
#    Epoch  140: Loss=3.28e-04, PDE=3.28e-04, θ=0.179±0.004
# ...

# %% [markdown]
# ### Wave Equation

# %%
results, domain, title = test_input_features_single_pde(
        pde_type='wave',
        n_runs=5,
        epochs=200,
        verbose=True
    )
    
plot_input_features_comparison(results, pde_type='wave', feature_sets={
            'no_grad': FEATURE_SETS['no_grad'],
            'default': FEATURE_SETS['default'],
            'with_y': FEATURE_SETS['with_y'],
            'with_t_norm': FEATURE_SETS['with_t_norm'],
            'with_y_abs':FEATURE_SETS['with_y'],
            'with_laplacian':FEATURE_SETS['with_laplacian'],
            'full': FEATURE_SETS['full']
        })
# Out:
# ...
# INPUT FEATURES TESTING: Wave Equation
# Feature sets: ['no_grad', 'default', 'with_y', 'with_t_norm', 'with_y_abs', 'with_laplacian', 'full']
# Runs per set: 5
# Model params: n_steps=3, n_iterations=3, lr=0.001
# ...
#
#
# ...
# Testing: no_grad
# Features (3): ['x', 't', 't_next']
# Theta params: 11
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# LF-PINN Input Features Test
# PDE: wave | Steps: 3 | Theta params: 11
# Input features (3): ['x', 't', 't_next']
# Initial theta: 0.5
# ...
#
#    Epoch    0: Loss=2.43e+00, PDE=2.43e+00, θ=0.500±0.000
#    Epoch   20: Loss=1.19e+00, PDE=1.19e+00, θ=0.492±0.000
#    Epoch   40: Loss=1.36e+00, PDE=1.36e+00, θ=0.483±0.001
#    Epoch   60: Loss=5.93e-01, PDE=5.93e-01, θ=0.473±0.001
#    Epoch   80: Loss=6.88e-01, PDE=6.88e-01, θ=0.460±0.001
#    Epoch  100: Loss=3.60e-01, PDE=3.60e-01, θ=0.447±0.001
#    Epoch  120: Loss=1.03e-01, PDE=1.03e-01, θ=0.432±0.001
#    Epoch  140: Loss=4.25e-02, PDE=4.25e-02, θ=0.417±0.001
#    Epoch  160: Loss=4.96e-02, PDE=4.96e-02, θ=0.415±0.002
# ...
