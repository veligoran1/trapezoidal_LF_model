# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import test_activations_single_pde

from utils.plot_utils import plot_activation_comparison

# %% [markdown]
# ### Activation Functions TEST - Heat

# %%
results, domain, title = test_activations_single_pde('heat', n_runs=5, epochs=300)
plot_activation_comparison(results, title, domain)
# Out:
# ...
# ACTIVATION TESTING: Heat Equation
# Activations: ['tanh', 'softplus', 'gelu', 'leakyrelu_001', 'leakyrelu_005', 'leakyrelu_01', 'leakyrelu_02', 'elu']
# Runs per activation: 5
# ...
#
#
# ...
# Testing activation: TANH
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Activation: TANH | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ...
#
#    Epoch    0: Loss=6.18e-03, PDE=6.18e-03, θ=0.388±0.002
#    Epoch   30: Loss=4.64e-03, PDE=4.64e-03, θ=0.384±0.002
#    Epoch   60: Loss=4.30e-03, PDE=4.30e-03, θ=0.385±0.002
#    Epoch   90: Loss=5.98e-03, PDE=5.98e-03, θ=0.377±0.003
#    Epoch  120: Loss=2.64e-03, PDE=2.64e-03, θ=0.376±0.005
#    Epoch  150: Loss=4.23e-03, PDE=4.23e-03, θ=0.365±0.012
#    Epoch  180: Loss=1.25e-03, PDE=1.25e-03, θ=0.346±0.025
#    Epoch  210: Loss=1.04e-03, PDE=1.04e-03, θ=0.319±0.033
#    Epoch  240: Loss=8.07e-04, PDE=8.07e-04, θ=0.313±0.042
#    Epoch  270: Loss=2.01e-04, PDE=2.01e-04, θ=0.310±0.047
# ...

# %% [markdown]
# ### Activation Functions TEST - Wave

# %%
results, domain, title = test_activations_single_pde('wave', n_runs=5, epochs=300)
plot_activation_comparison(results, title, domain)
# Out:
# ...
# ACTIVATION TESTING: Wave Equation
# Activations: ['tanh', 'softplus', 'gelu', 'leakyrelu_001', 'leakyrelu_005', 'leakyrelu_01', 'leakyrelu_02', 'elu']
# Runs per activation: 5
# ...
#
#
# ...
# Testing activation: TANH
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Activation: TANH | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ...
#
#    Epoch    0: Loss=1.77e+00, PDE=1.77e+00, θ=0.489±0.002
#    Epoch   30: Loss=1.45e+00, PDE=1.45e+00, θ=0.472±0.003
#    Epoch   60: Loss=3.43e-01, PDE=3.43e-01, θ=0.454±0.003
#    Epoch   90: Loss=2.56e-01, PDE=2.56e-01, θ=0.434±0.004
#    Epoch  120: Loss=3.74e-02, PDE=3.74e-02, θ=0.414±0.006
#    Epoch  150: Loss=5.94e-02, PDE=5.94e-02, θ=0.416±0.006
#    Epoch  180: Loss=3.39e-02, PDE=3.39e-02, θ=0.415±0.006
#    Epoch  210: Loss=7.60e-02, PDE=7.60e-02, θ=0.416±0.005
#    Epoch  240: Loss=4.26e-02, PDE=4.26e-02, θ=0.414±0.005
#    Epoch  270: Loss=2.54e-02, PDE=2.54e-02, θ=0.414±0.006
# ...

# %% [markdown]
# ### Activation Functions TEST - Burgers

# %%
results, domain, title = test_activations_single_pde('burgers', n_runs=5, epochs=300)
plot_activation_comparison(results, title, domain)
# Out:
# ...
# ACTIVATION TESTING: Burgers Equation
# Activations: ['tanh', 'softplus', 'gelu', 'leakyrelu_001', 'leakyrelu_005', 'leakyrelu_01', 'leakyrelu_02', 'elu']
# Runs per activation: 5
# ...
#
#
# ...
# Testing activation: TANH
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Activation: TANH | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.0005
# ...
#
#    Epoch    0: Loss=2.69e+00, PDE=2.69e+00, θ=0.196±0.002
#    Epoch   30: Loss=2.56e+00, PDE=2.56e+00, θ=0.195±0.002
#    Epoch   60: Loss=2.47e+00, PDE=2.47e+00, θ=0.195±0.003
#    Epoch   90: Loss=3.40e+00, PDE=3.40e+00, θ=0.194±0.003
#    Epoch  120: Loss=7.72e-01, PDE=7.72e-01, θ=0.191±0.003
#    Epoch  150: Loss=2.18e+00, PDE=2.18e+00, θ=0.189±0.003
#    Epoch  180: Loss=7.54e-01, PDE=7.54e-01, θ=0.189±0.003
#    Epoch  210: Loss=4.48e+00, PDE=4.48e+00, θ=0.186±0.003
#    Epoch  240: Loss=4.69e-01, PDE=4.69e-01, θ=0.186±0.003
#    Epoch  270: Loss=6.87e-01, PDE=6.87e-01, θ=0.184±0.004
# ...

# %% [markdown]
# ### Activation Functions TEST - Reaction-Diffusion

# %%
results, domain, title = test_activations_single_pde('reaction_diffusion', n_runs=5, epochs=300)
plot_activation_comparison(results, title, domain)
# Out:
# ...
# ACTIVATION TESTING: Reaction-Diffusion
# Activations: ['tanh', 'softplus', 'gelu', 'leakyrelu_001', 'leakyrelu_005', 'leakyrelu_01', 'leakyrelu_02', 'elu']
# Runs per activation: 5
# ...
#
#
# ...
# Testing activation: TANH
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Activation: TANH | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.005
# ...
#
#    Epoch    0: Loss=1.44e-02, PDE=1.44e-02, θ=0.292±0.003
#    Epoch   30: Loss=3.57e-03, PDE=3.57e-03, θ=0.255±0.006
#    Epoch   60: Loss=1.46e-02, PDE=1.46e-02, θ=0.218±0.007
#    Epoch   90: Loss=7.81e-03, PDE=7.81e-03, θ=0.191±0.007
#    Epoch  120: Loss=7.76e-05, PDE=7.76e-05, θ=0.175±0.007
#    Epoch  150: Loss=1.96e-04, PDE=1.96e-04, θ=0.172±0.008
#    Epoch  180: Loss=7.82e-05, PDE=7.82e-05, θ=0.163±0.007
#    Epoch  210: Loss=2.22e-03, PDE=2.22e-03, θ=0.154±0.005
#    Epoch  240: Loss=1.54e-04, PDE=1.54e-04, θ=0.151±0.006
#    Epoch  270: Loss=2.07e-04, PDE=2.07e-04, θ=0.147±0.007
# ...
