# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import torch
import numpy as np
import random
from utils.benchmark_utils import test_lr_single_pde
from utils.plot_utils import plot_lr_comparison

# %% [markdown]
# ### Learning Rate Study - Heat Equation

# %%
results_heat = test_lr_single_pde('heat', epochs=200, max_time=1000.0, n_runs=5,  n_steps = 4)
plot_lr_comparison(results_heat, 'Heat Equation')
# Out:
# ==================================================
# Testing LR = 0.0005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.87e-02, epochs=200, time=31.4s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.89e-02, epochs=200, time=31.5s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.86e-02, epochs=200, time=31.4s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.91e-02, epochs=200, time=31.5s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.84e-02, epochs=200, time=31.9s
#   → L2RE: 1.87e-02 ± 2.22e-04
#
# ==================================================
# Testing LR = 0.001
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.84e-02, epochs=200, time=31.7s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.89e-02, epochs=200, time=31.6s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.83e-02, epochs=200, time=31.5s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.90e-02, epochs=200, time=30.8s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.73e-02, epochs=200, time=30.3s
#   → L2RE: 1.84e-02 ± 5.96e-04
#
# ==================================================
# Testing LR = 0.0025
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.61e-02, epochs=200, time=30.3s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.63e-02, epochs=200, time=30.3s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.36e-02, epochs=200, time=30.3s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.60e-02, epochs=200, time=30.4s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.09e-02, epochs=200, time=30.4s
#   → L2RE: 1.46e-02 ± 2.10e-03
#
# ==================================================
# Testing LR = 0.005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.23e-02, epochs=200, time=30.3s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.55e-02, epochs=200, time=30.2s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.34e-02, epochs=200, time=30.3s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.25e-02, epochs=200, time=30.7s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.34e-02, epochs=200, time=30.2s
#   → L2RE: 1.34e-02 ± 1.15e-03
#
# ==================================================
# Testing LR = 0.01
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.44e-02, epochs=200, time=30.2s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.43e-02, epochs=200, time=30.3s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.51e-02, epochs=200, time=30.2s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.40e-02, epochs=200, time=30.2s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.46e-02, epochs=200, time=30.2s
#   → L2RE: 1.45e-02 ± 3.68e-04
#
# ==================================================
# Testing LR = 0.05
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.46e-02, epochs=200, time=30.2s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.42e-02, epochs=200, time=30.2s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.48e-02, epochs=200, time=30.1s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.44e-02, epochs=200, time=30.3s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.4
# ============================================================
#
# L2RE=1.40e-02, epochs=200, time=30.4s
#   → L2RE: 1.44e-02 ± 2.74e-04
# ================================================================================
# LR           L2RE Mean       L2RE Std        Epochs       Final Loss
# --------------------------------------------------------------------------------
# 0.0005       1.8741e-02      2.2155e-04      200          4.4564e-03
# 0.001        1.8368e-02      5.9582e-04      200          4.2260e-03
# 0.0025       1.4577e-02      2.0972e-03      200          2.4246e-03
# 0.005        1.3411e-02      1.1485e-03      200          3.4339e-04
# 0.01         1.4461e-02      3.6819e-04      200          4.2250e-05
# 0.05         1.4407e-02      2.7424e-04      200          1.7440e-05
# ================================================================================
#
# ✓ Best LR: 0.005 with L2RE = 1.3411e-02

# %% [markdown]
# ### Learning Rate Study - Wave Equation

# %%
results_wave = test_lr_single_pde('wave', epochs=200, max_time=1000.0, n_runs=5,  n_steps = 3, n_iterations = 3)
plot_lr_comparison(results_wave, 'Wave Equation')
# Out:
# ==================================================
# Testing LR = 0.0005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0005
# Initial theta: 0.5
# ============================================================
#
# L2RE=5.14e-02, epochs=200, time=108.5s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0005
# Initial theta: 0.5
# ============================================================
#
# L2RE=5.78e-02, epochs=200, time=109.9s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0005
# Initial theta: 0.5
# ============================================================
#
# L2RE=6.07e-02, epochs=200, time=109.3s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0005
# Initial theta: 0.5
# ============================================================
#
# L2RE=5.13e-02, epochs=200, time=109.2s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0005
# Initial theta: 0.5
# ============================================================
#
# L2RE=6.02e-02, epochs=200, time=110.5s
#   → L2RE: 5.63e-02 ± 4.14e-03
#
# ==================================================
# Testing LR = 0.001
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.02e-02, epochs=200, time=111.3s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.00e-02, epochs=200, time=111.3s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.02e-02, epochs=200, time=111.8s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.00e-02, epochs=200, time=110.5s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.02e-02, epochs=200, time=110.4s
#   → L2RE: 3.01e-02 ± 1.09e-04
#
# ==================================================
# Testing LR = 0.0025
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0025
# Initial theta: 0.5
# ============================================================
#
# L2RE=2.99e-02, epochs=200, time=110.5s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0025
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.06e-02, epochs=200, time=110.5s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0025
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.01e-02, epochs=200, time=109.7s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0025
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.06e-02, epochs=200, time=109.9s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.0025
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.05e-02, epochs=200, time=112.9s
#   → L2RE: 3.03e-02 ± 2.88e-04
#
# ==================================================
# Testing LR = 0.005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.005
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.03e-02, epochs=200, time=110.9s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.005
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.06e-02, epochs=200, time=109.9s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.005
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.05e-02, epochs=200, time=109.9s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.005
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.24e-02, epochs=200, time=110.2s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.005
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.37e-02, epochs=200, time=110.4s
#   → L2RE: 3.15e-02 ± 1.33e-03
#
# ==================================================
# Testing LR = 0.01
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.01
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.25e-02, epochs=200, time=116.8s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.01
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.35e-02, epochs=200, time=127.4s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.01
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.41e-02, epochs=200, time=132.7s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.01
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.37e-02, epochs=200, time=134.2s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.01
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.41e-02, epochs=200, time=131.0s
#   → L2RE: 3.36e-02 ± 5.98e-04
#
# ==================================================
# Testing LR = 0.05
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.05
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.30e-02, epochs=200, time=130.1s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.05
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.29e-02, epochs=200, time=129.9s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.05
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.37e-02, epochs=200, time=130.3s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.05
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.32e-02, epochs=200, time=130.1s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.05
# Initial theta: 0.5
# ============================================================
#
# L2RE=3.50e-02, epochs=200, time=130.1s
#   → L2RE: 3.36e-02 ± 7.74e-04
# ================================================================================
# LR           L2RE Mean       L2RE Std        Epochs       Final Loss
# --------------------------------------------------------------------------------
# 0.0005       5.6277e-02      4.1408e-03      200          3.1054e-01
# 0.001        3.0120e-02      1.0893e-04      200          4.8892e-02
# 0.0025       3.0338e-02      2.8775e-04      200          4.0021e-02
# 0.005        3.1502e-02      1.3326e-03      200          2.4413e-02
# 0.01         3.3601e-02      5.9803e-04      200          1.6446e-02
# 0.05         3.3552e-02      7.7405e-04      200          1.6336e-02
# ================================================================================
#
# ✓ Best LR: 0.001 with L2RE = 3.0120e-02

# %% [markdown]
# ### Learning Rate Study - Burgers Equation (2,2)

# %%
results_burgers = test_lr_single_pde('burgers', epochs=200, max_time=1000.0, n_runs=5,  n_steps = 2, n_iterations = 2)
plot_lr_comparison(results_burgers, 'Burgers Equation')
# Out:
# ==================================================
# Testing LR = 0.0005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.2
# ============================================================
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   phi_x, _ = quad(integrand_phi_x, limit_low, limit_high,
# L2RE=1.64e-01, epochs=200, time=74.1s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.65e-01, epochs=200, time=74.0s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.65e-01, epochs=200, time=73.9s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.65e-01, epochs=200, time=73.8s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.65e-01, epochs=200, time=73.7s
#   → L2RE: 1.65e-01 ± 2.37e-04
#
# ==================================================
# Testing LR = 0.001
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.65e-01, epochs=200, time=74.9s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.66e-01, epochs=200, time=75.0s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.67e-01, epochs=200, time=75.1s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.66e-01, epochs=200, time=74.9s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.67e-01, epochs=200, time=74.8s
#   → L2RE: 1.66e-01 ± 7.32e-04
#
# ==================================================
# Testing LR = 0.0025
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.67e-01, epochs=200, time=74.8s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.69e-01, epochs=200, time=74.8s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.74e-01, epochs=200, time=74.3s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.71e-01, epochs=200, time=73.8s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.72e-01, epochs=200, time=73.9s
#   → L2RE: 1.71e-01 ± 2.31e-03
#
# ==================================================
# Testing LR = 0.005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.68e-01, epochs=200, time=73.6s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.72e-01, epochs=200, time=73.6s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.76e-01, epochs=200, time=73.7s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.75e-01, epochs=200, time=73.7s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.75e-01, epochs=200, time=73.9s
#   → L2RE: 1.73e-01 ± 3.01e-03
#
# ==================================================
# Testing LR = 0.01
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.64e-01, epochs=200, time=73.7s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.70e-01, epochs=200, time=73.7s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.69e-01, epochs=200, time=73.6s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.74e-01, epochs=200, time=73.7s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.77e-01, epochs=200, time=73.8s
#   → L2RE: 1.71e-01 ± 4.25e-03
#
# ==================================================
# Testing LR = 0.05
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.62e-01, epochs=200, time=73.9s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.75e-01, epochs=200, time=73.7s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.83e-01, epochs=200, time=73.8s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.85e-01, epochs=200, time=73.6s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.2
# ============================================================
#
# L2RE=1.80e-01, epochs=200, time=73.8s
#   → L2RE: 1.77e-01 ± 8.40e-03
# ================================================================================
# LR           L2RE Mean       L2RE Std        Epochs       Final Loss
# --------------------------------------------------------------------------------
# 0.0005       1.6466e-01      2.3743e-04      200          2.6329e+00
# 0.001        1.6636e-01      7.3233e-04      200          2.5027e+00
# 0.0025       1.7074e-01      2.3136e-03      200          2.3415e+00
# 0.005        1.7324e-01      3.0083e-03      200          2.2767e+00
# 0.01         1.7076e-01      4.2535e-03      200          2.1700e+00
# 0.05         1.7715e-01      8.3997e-03      200          2.0818e+00
# ================================================================================
#
# ✓ Best LR: 0.0005 with L2RE = 1.6466e-01

# %% [markdown]
# ### Learning Rate Study - Reaction-Diffusion Equation (2,2)

# %%
results_rd = test_lr_single_pde('reaction_diffusion', epochs=200, max_time=1000.0, n_runs=5,  n_steps = 2, n_iterations = 2)
plot_lr_comparison(results_rd, 'Reaction-Diffusion Equation')
# Out:
# ==================================================
# Testing LR = 0.0005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.2s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.3s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.8s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.7s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.1s
#   → L2RE: 1.36e-01 ± 8.43e-06
#
# ==================================================
# Testing LR = 0.001
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.001
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   → L2RE: 1.36e-01 ± 9.87e-06
#
# ==================================================
# Testing LR = 0.0025
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.1s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.3s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0025
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   → L2RE: 1.36e-01 ± 8.71e-06
#
# ==================================================
# Testing LR = 0.005
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.5s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   → L2RE: 1.36e-01 ± 9.49e-06
#
# ==================================================
# Testing LR = 0.01
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.6s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.8s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.01
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.8s
#   → L2RE: 1.36e-01 ± 9.87e-06
#
# ==================================================
# Testing LR = 0.05
# ==================================================
#   Run 1/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.9s
#   Run 2/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.8s
#   Run 3/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=88.8s
#   Run 4/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.0s
#   Run 5/5...
# ============================================================
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.05
# Initial theta: 0.3
# ============================================================
#
# L2RE=1.36e-01, epochs=200, time=89.2s
#   → L2RE: 1.36e-01 ± 1.00e-04
# ================================================================================
# LR           L2RE Mean       L2RE Std        Epochs       Final Loss
# --------------------------------------------------------------------------------
# 0.0005       1.3591e-01      8.4284e-06      200          4.8380e-02
# 0.001        1.3586e-01      9.8683e-06      200          3.0775e-02
# 0.0025       1.3582e-01      8.7117e-06      200          9.9451e-03
# 0.005        1.3582e-01      9.4852e-06      200          3.1808e-03
# 0.01         1.3583e-01      9.8736e-06      200          1.0693e-03
# 0.05         1.3594e-01      1.0003e-04      200          3.8733e-04
# ================================================================================
#
# ✓ Best LR: 0.0025 with L2RE = 1.3582e-01
