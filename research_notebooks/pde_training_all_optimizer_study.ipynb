# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import test_optimizers_single_pde
from utils.plot_utils import plot_optimizers_comparison, plot_optimizers_detailed

# %% [markdown]
# ## All Optimizer Comparison: Adam, AdamW, SGD Momentum, SGD Nesterov, RmsProp, nAdam, rAdam, AdaMax

# %% [markdown]
# ### Optimizer Test - Heat Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'heat',
    n_runs=5,
    epochs=300,
    lr=0.05
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ...
# OPTIMIZER TESTING: Heat Equation
# Optimizers: ['adam', 'adamw', 'adamw_wd001', 'sgd_momentum', 'sgd_nesterov', 'rmsprop', 'nadam', 'radam', 'adamax']
# Runs per optimizer: 5
# Parameters: n_steps=4, n_iterations=2, lr=0.05
# ...
#
#
# ...
# Testing optimizer: ADAM
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=1.2556e-02, Time=41.5s
#
#   Run 2/5 (seed=153)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=1.4200e-02, Time=42.5s
#
#   Run 3/5 (seed=264)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=1.2796e-02, Time=41.7s
#
#   Run 4/5 (seed=375)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.05
# ...
#
# ...

# %% [markdown]
# ### Optimizer Test - Burgers Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'burgers',
    n_runs=5,
    epochs=300,
    lr=0.05
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ...
# OPTIMIZER TESTING: Burgers Equation
# Optimizers: ['adam', 'adamw', 'adamw_wd001', 'sgd_momentum', 'sgd_nesterov', 'rmsprop', 'nadam', 'radam', 'adamax']
# Runs per optimizer: 5
# Parameters: n_steps=2, n_iterations=2, lr=0.05
# ...
#
#
# ...
# Testing optimizer: ADAM
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.05
# ...
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:635: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   try:
#     ✓ L2RE=1.6107e-01, Time=100.5s
#
#   Run 2/5 (seed=153)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=1.8389e-01, Time=99.6s
#
#   Run 3/5 (seed=264)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# ...

# %% [markdown]
# ### Optimizer Test - Reaction-Diffusion Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'reaction_diffusion',
    n_runs=5,
    epochs=300,
    lr=0.05
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ...
# OPTIMIZER TESTING: Reaction-Diffusion
# Optimizers: ['adam', 'adamw', 'adamw_wd001', 'sgd_momentum', 'sgd_nesterov', 'rmsprop', 'nadam', 'radam', 'adamax']
# Runs per optimizer: 5
# Parameters: n_steps=2, n_iterations=2, lr=0.05
# ...
#
#
# ...
# Testing optimizer: ADAM
# ...
#
#   Run 1/5 (seed=42)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=6.9387e-02, Time=128.3s
#
#   Run 2/5 (seed=153)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=6.9262e-02, Time=129.0s
#
#   Run 3/5 (seed=264)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.05
# ...
#
#     ✓ L2RE=6.9398e-02, Time=127.2s
#
#   Run 4/5 (seed=375)
#
# ...
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# ...
