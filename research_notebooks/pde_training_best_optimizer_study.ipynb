# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import test_optimizers_single_pde
from utils.plot_utils import plot_optimizers_comparison, plot_optimizers_detailed

# %% [markdown]
# ## Best Optimizer Comparison: Adam, AdamW, RmsProp

# %% [markdown]
# ### Best Optimizer Test - Heat Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'heat',
    n_runs=3,
    epochs=500,
    lr=0.005
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ================================================================================
# OPTIMIZER TESTING: Heat Equation
# Optimizers: ['adam', 'adamw', 'adamw_wd01', 'adamw_wd001', 'rmsprop', 'rmsprop_centered']
# Runs per optimizer: 3
# Parameters: n_steps=4, n_iterations=2, lr=0.005
# ================================================================================
#
#
# ============================================================
# Testing optimizer: ADAM
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1713e-02, Time=87.7s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.2903e-02, Time=84.9s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAM | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1867e-02, Time=82.2s
#
# ============================================================
# Testing optimizer: ADAMW
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1692e-02, Time=86.1s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.2896e-02, Time=88.9s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1796e-02, Time=92.3s
#
# ============================================================
# Testing optimizer: ADAMW_WD01
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1648e-02, Time=92.6s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.2961e-02, Time=92.9s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1367e-02, Time=85.9s
#
# ============================================================
# Testing optimizer: ADAMW_WD001
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1711e-02, Time=83.8s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.2902e-02, Time=83.9s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.1860e-02, Time=84.5s
#
# ============================================================
# Testing optimizer: RMSPROP
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: RMSPROP | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.3468e-02, Time=85.3s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: RMSPROP | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.3600e-02, Time=88.0s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: RMSPROP | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.4512e-02, Time=86.5s
#
# ============================================================
# Testing optimizer: RMSPROP_CENTERED
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.3867e-02, Time=84.7s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.3790e-02, Time=83.8s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: heat | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 4 | Iterations: 2 | LR: 0.005
# ============================================================
#
#     ✓ L2RE=1.4567e-02, Time=84.0s
# ====================================================================================================
# SUMMARY: Heat Equation - Optimizer Comparison
# ====================================================================================================
# Optimizer          L2RE                     Time (s)         Final θ      Note
# ----------------------------------------------------------------------------------------------------
# adam               1.22e-02 ± 5.28e-04      85.0 ± 2.3       0.333
# adamw              1.21e-02 ± 5.45e-04      89.1 ± 2.5       0.334
# adamw_wd01         1.20e-02 ± 6.95e-04      90.5 ± 3.2       0.341        BEST L2RE
# adamw_wd001        1.22e-02 ± 5.30e-04      84.1 ± 0.3       0.333        FASTEST
# rmsprop            1.39e-02 ± 4.64e-04      86.6 ± 1.1       0.293
# rmsprop_centered   1.41e-02 ± 3.50e-04      84.1 ± 0.4       0.294
# ====================================================================================================
#
# ============================================================
# EFFICIENCY ANALYSIS (L2RE per second)
# ============================================================
#   1. adamw_wd01      efficiency=1.33e-04 (L2RE=1.20e-02, time=90.5s)
#   2. adamw           efficiency=1.36e-04 (L2RE=1.21e-02, time=89.1s)
#   3. adam            efficiency=1.43e-04 (L2RE=1.22e-02, time=85.0s)
#   4. adamw_wd001     efficiency=1.45e-04 (L2RE=1.22e-02, time=84.1s)
#   5. rmsprop         efficiency=1.60e-04 (L2RE=1.39e-02, time=86.6s)
#   6. rmsprop_centered efficiency=1.67e-04 (L2RE=1.41e-02, time=84.1s)
# ============================================================

# %% [markdown]
# ### Best Optimizer Test - Wave Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'wave',
    n_runs=3,
    epochs=500,
    lr=0.001
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ================================================================================
# OPTIMIZER TESTING: Wave Equation
# Optimizers: ['adam', 'adamw', 'adamw_wd01', 'adamw_wd001', 'rmsprop', 'rmsprop_centered']
# Runs per optimizer: 3
# Parameters: n_steps=3, n_iterations=3, lr=0.001
# ================================================================================
#
#
# ============================================================
# Testing optimizer: ADAM
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAM | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=2.9994e-02, Time=322.0s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAM | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0443e-02, Time=338.6s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAM | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.2277e-02, Time=348.6s
#
# ============================================================
# Testing optimizer: ADAMW
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=2.9995e-02, Time=342.0s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0442e-02, Time=344.5s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.2260e-02, Time=348.5s
#
# ============================================================
# Testing optimizer: ADAMW_WD01
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0006e-02, Time=349.9s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0427e-02, Time=345.0s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.2117e-02, Time=335.2s
#
# ============================================================
# Testing optimizer: ADAMW_WD001
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=2.9994e-02, Time=343.1s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0443e-02, Time=342.5s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.2275e-02, Time=345.5s
#
# ============================================================
# Testing optimizer: RMSPROP
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: RMSPROP | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0310e-02, Time=349.5s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: RMSPROP | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.1050e-02, Time=335.8s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: RMSPROP | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.3671e-02, Time=328.9s
#
# ============================================================
# Testing optimizer: RMSPROP_CENTERED
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.0381e-02, Time=331.6s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.1142e-02, Time=331.4s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: wave | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 3 | Iterations: 3 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=3.3927e-02, Time=327.7s
# ====================================================================================================
# SUMMARY: Wave Equation - Optimizer Comparison
# ====================================================================================================
# Optimizer          L2RE                     Time (s)         Final θ      Note
# ----------------------------------------------------------------------------------------------------
# adam               3.09e-02 ± 9.87e-04      336.4 ± 10.9     0.404
# adamw              3.09e-02 ± 9.80e-04      345.0 ± 2.7      0.404
# adamw_wd01         3.09e-02 ± 9.12e-04      343.3 ± 6.1      0.404        BEST L2RE
# adamw_wd001        3.09e-02 ± 9.86e-04      343.7 ± 1.3      0.404
# rmsprop            3.17e-02 ± 1.44e-03      338.1 ± 8.6      0.400
# rmsprop_centered   3.18e-02 ± 1.52e-03      330.2 ± 1.8      0.399        FASTEST
# ====================================================================================================
#
# ============================================================
# EFFICIENCY ANALYSIS (L2RE per second)
# ============================================================
#   1. adamw           efficiency=8.96e-05 (L2RE=3.09e-02, time=345.0s)
#   2. adamw_wd01      efficiency=8.99e-05 (L2RE=3.09e-02, time=343.3s)
#   3. adamw_wd001     efficiency=8.99e-05 (L2RE=3.09e-02, time=343.7s)
#   4. adam            efficiency=9.19e-05 (L2RE=3.09e-02, time=336.4s)
#   5. rmsprop         efficiency=9.37e-05 (L2RE=3.17e-02, time=338.1s)
#   6. rmsprop_centered efficiency=9.64e-05 (L2RE=3.18e-02, time=330.2s)
# ============================================================

# %% [markdown]
# ### Best Optimizer Test - Burgers Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'burgers',
    n_runs=3,
    epochs=500,
    lr=0.001
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ================================================================================
# OPTIMIZER TESTING: Burgers Equation
# Optimizers: ['adam', 'adamw', 'adamw_wd01', 'adamw_wd001', 'rmsprop', 'rmsprop_centered']
# Runs per optimizer: 3
# Parameters: n_steps=2, n_iterations=2, lr=0.001
# ================================================================================
#
#
# ============================================================
# Testing optimizer: ADAM
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   phi_x, _ = quad(integrand_phi_x, limit_low, limit_high,
#     ✓ L2RE=1.5911e-01, Time=182.3s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6110e-01, Time=181.0s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5689e-01, Time=179.4s
#
# ============================================================
# Testing optimizer: ADAMW
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5913e-01, Time=179.6s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6117e-01, Time=187.4s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5690e-01, Time=182.7s
#
# ============================================================
# Testing optimizer: ADAMW_WD01
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5944e-01, Time=178.4s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6190e-01, Time=179.4s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5714e-01, Time=180.4s
#
# ============================================================
# Testing optimizer: ADAMW_WD001
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5911e-01, Time=175.3s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6110e-01, Time=174.7s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5689e-01, Time=174.2s
#
# ============================================================
# Testing optimizer: RMSPROP
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: RMSPROP | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6049e-01, Time=174.8s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: RMSPROP | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5900e-01, Time=174.2s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: RMSPROP | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5724e-01, Time=174.2s
#
# ============================================================
# Testing optimizer: RMSPROP_CENTERED
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6675e-01, Time=175.4s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.6108e-01, Time=184.8s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: burgers | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.5979e-01, Time=181.0s
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/plot_utils.py:1509: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
# ====================================================================================================
# SUMMARY: Burgers Equation - Optimizer Comparison
# ====================================================================================================
# Optimizer          L2RE                     Time (s)         Final θ      Note
# ----------------------------------------------------------------------------------------------------
# adam               1.59e-01 ± 1.72e-03      180.9 ± 1.2      0.253
# adamw              1.59e-01 ± 1.74e-03      183.2 ± 3.2      0.254
# adamw_wd01         1.59e-01 ± 1.94e-03      179.4 ± 0.8      0.260
# adamw_wd001        1.59e-01 ± 1.72e-03      174.7 ± 0.5      0.253
# rmsprop            1.59e-01 ± 1.32e-03      174.4 ± 0.3      0.224        BEST L2RE, FASTEST
# rmsprop_centered   1.63e-01 ± 3.02e-03      180.4 ± 3.8      0.196
# ====================================================================================================
#
# ============================================================
# EFFICIENCY ANALYSIS (L2RE per second)
# ============================================================
#   1. adamw           efficiency=8.68e-04 (L2RE=1.59e-01, time=183.2s)
#   2. adam            efficiency=8.79e-04 (L2RE=1.59e-01, time=180.9s)
#   3. adamw_wd01      efficiency=8.89e-04 (L2RE=1.59e-01, time=179.4s)
#   4. rmsprop_centered efficiency=9.01e-04 (L2RE=1.63e-01, time=180.4s)
#   5. adamw_wd001     efficiency=9.10e-04 (L2RE=1.59e-01, time=174.7s)
#   6. rmsprop         efficiency=9.11e-04 (L2RE=1.59e-01, time=174.4s)
# ============================================================

# %% [markdown]
# ### Best Optimizer Test - Reaction-Diffusion Equation

# %%
results, domain, title = test_optimizers_single_pde(
    'reaction_diffusion',
    n_runs=3,
    epochs=500,
    lr=0.001
)

best_opt = plot_optimizers_comparison(results, title)

plot_optimizers_detailed(results, title, top_n=4)
# Out:
# ================================================================================
# OPTIMIZER TESTING: Reaction-Diffusion
# Optimizers: ['adam', 'adamw', 'adamw_wd01', 'adamw_wd001', 'rmsprop', 'rmsprop_centered']
# Runs per optimizer: 3
# Parameters: n_steps=2, n_iterations=2, lr=0.001
# ================================================================================
#
#
# ============================================================
# Testing optimizer: ADAM
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3604e-01, Time=221.9s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3602e-01, Time=224.3s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAM | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3612e-01, Time=225.2s
#
# ============================================================
# Testing optimizer: ADAMW
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3605e-01, Time=224.2s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3603e-01, Time=218.4s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3612e-01, Time=234.0s
#
# ============================================================
# Testing optimizer: ADAMW_WD01
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3607e-01, Time=231.4s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3605e-01, Time=232.2s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW_WD01 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3615e-01, Time=229.8s
#
# ============================================================
# Testing optimizer: ADAMW_WD001
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3604e-01, Time=230.7s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3602e-01, Time=228.5s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: ADAMW_WD001 | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3612e-01, Time=227.0s
#
# ============================================================
# Testing optimizer: RMSPROP
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: RMSPROP | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3593e-01, Time=223.3s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: RMSPROP | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3591e-01, Time=227.2s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: RMSPROP | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3598e-01, Time=231.6s
#
# ============================================================
# Testing optimizer: RMSPROP_CENTERED
# ============================================================
#
#   Run 1/3 (seed=42)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3589e-01, Time=231.5s
#
#   Run 2/3 (seed=153)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3587e-01, Time=241.0s
#
#   Run 3/3 (seed=264)
#
# ============================================================
# Low-Fidelity PINN (Optimizer Test)
# PDE: reaction_diffusion | Optimizer: RMSPROP_CENTERED | Params: 13
# Max Steps: 2 | Iterations: 2 | LR: 0.001
# ============================================================
#
#     ✓ L2RE=1.3594e-01, Time=245.6s
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/plot_utils.py:1509: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# ====================================================================================================
# SUMMARY: Reaction-Diffusion - Optimizer Comparison
# ====================================================================================================
# Optimizer          L2RE                     Time (s)         Final θ      Note
# ----------------------------------------------------------------------------------------------------
# adam               1.36e-01 ± 4.18e-05      223.8 ± 1.4      0.299        FASTEST
# adamw              1.36e-01 ± 4.20e-05      225.5 ± 6.5      0.299
# adamw_wd01         1.36e-01 ± 4.37e-05      231.1 ± 1.0      0.304
# adamw_wd001        1.36e-01 ± 4.18e-05      228.7 ± 1.5      0.299
# rmsprop            1.36e-01 ± 3.29e-05      227.4 ± 3.4      0.266
# rmsprop_centered   1.36e-01 ± 2.89e-05      239.4 ± 5.9      0.248        BEST L2RE
# ====================================================================================================
#
# ============================================================
# EFFICIENCY ANALYSIS (L2RE per second)
# ============================================================
#   1. rmsprop_centered efficiency=5.68e-04 (L2RE=1.36e-01, time=239.4s)
#   2. adamw_wd01      efficiency=5.89e-04 (L2RE=1.36e-01, time=231.1s)
#   3. adamw_wd001     efficiency=5.95e-04 (L2RE=1.36e-01, time=228.7s)
#   4. rmsprop         efficiency=5.98e-04 (L2RE=1.36e-01, time=227.4s)
#   5. adamw           efficiency=6.03e-04 (L2RE=1.36e-01, time=225.5s)
#   6. adam            efficiency=6.08e-04 (L2RE=1.36e-01, time=223.8s)
# ============================================================
