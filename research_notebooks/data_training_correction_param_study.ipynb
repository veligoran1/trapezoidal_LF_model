# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

from utils.benchmark_utils import test_theta_param_modes
from utils.plot_utils import plot_correction_comparison
from utils.config import DOMAINS, PDE_CONFIGS

# %% [markdown]
# ## Correction Params on Data Finetuning stage

# %% [markdown]
# ### No Noise

# %% [markdown]
# #### Heat Equation

# %%
results = test_theta_param_modes(
    pde_type='heat',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=1000, 
    pretrain_lr=0.005,
    finetune_lr=0.0005,
    n_data=50,
    noise_level=0.00,
    freeze_base=True
)

plot_correction_comparison(results, pde_type='heat')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: none
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=1.2793e-02 → finetune=3.6533e-03 (Δ=+71.4%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_bias
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 4
# Total trainable: 17
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   per_step_bias       : pretrain=1.2793e-02 → finetune=6.3097e-03 (Δ=+50.7%, corr_params=4)
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_gate
# Steps: 4 | Iterations: 2
# ...

# %% [markdown]
# #### Wave Equation

# %%
results = test_theta_param_modes(
            pde_type='wave',
            n_runs=5,
            pretrain_epochs=140,
            finetune_epochs=1500,
            pretrain_lr=0.001,
            finetune_lr=0.0001,
            n_data=50,
            noise_level=0.00,
            freeze_base=True
        )

plot_correction_comparison(results, pde_type='wave')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: none
# Steps: 3 | Iterations: 3
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=3.0123e-02 → finetune=3.0437e-02 (Δ=-1.0%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: per_step_bias
# Steps: 3 | Iterations: 3
# Base theta_net params: 13
# Correction params: 3
# Total trainable: 16
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   per_step_bias       : pretrain=3.0123e-02 → finetune=3.0404e-02 (Δ=-0.9%, corr_params=3)
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: per_step_gate
# Steps: 3 | Iterations: 3
# ...

# %% [markdown]
# #### Burgers Equation

# %%
results = test_theta_param_modes(
    pde_type='burgers',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=1000,
    pretrain_lr=0.0005,
    finetune_lr=0.0001,
    n_data=50,
    noise_level=0.00,
    freeze_base=True
)

plot_correction_comparison(results, pde_type='burgers')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: burgers | Mode: none
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   phi_x, _ = quad(integrand_phi_x, limit_low, limit_high,
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=1.6236e-01 → finetune=1.7220e-01 (Δ=-6.1%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: burgers | Mode: per_step_bias
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# [ThetaParams] Corrections DISABLED
# ...

# %% [markdown]
# #### Reaction-Diffusion Equation

# %%
results = test_theta_param_modes(
            pde_type='reaction_diffusion',
            n_runs=5,
            pretrain_epochs=150,
            finetune_epochs=1000,
            pretrain_lr=0.005,
            finetune_lr=0.0001,
            n_data=50,
            noise_level=0.00,
            freeze_base=True
        )

plot_correction_comparison(results, pde_type='reaction_diffusion')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: reaction_diffusion | Mode: none
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=1.3583e-01 → finetune=1.3583e-01 (Δ=+0.0%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: reaction_diffusion | Mode: per_step_bias
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   per_step_bias       : pretrain=1.3583e-01 → finetune=1.3553e-01 (Δ=+0.2%, corr_params=2)
#
# ...
# LF-PINN Theta Params
# ...

# %% [markdown]
# ### 5% Noise in Data

# %% [markdown]
# #### Heat Equation

# %%
results = test_theta_param_modes(
    pde_type='heat',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=1000, 
    pretrain_lr=0.005,
    finetune_lr=0.0005,
    n_data=50,
    noise_level=0.05,
    freeze_base=True
)

plot_correction_comparison(results, pde_type='heat')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: none
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=1.2793e-02 → finetune=4.6310e-03 (Δ=+63.8%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_bias
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 4
# Total trainable: 17
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   per_step_bias       : pretrain=1.2793e-02 → finetune=6.7808e-03 (Δ=+47.0%, corr_params=4)
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_gate
# Steps: 4 | Iterations: 2
# ...

# %% [markdown]
# #### Wave Equation

# %%
results = test_theta_param_modes(
            pde_type='wave',
            n_runs=5,
            pretrain_epochs=140,
            finetune_epochs=1500,
            pretrain_lr=0.001,
            finetune_lr=0.0001,
            n_data=50,
            noise_level=0.05,
            freeze_base=True
        )

plot_correction_comparison(results, pde_type='wave')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: none
# Steps: 3 | Iterations: 3
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=3.0123e-02 → finetune=3.1477e-02 (Δ=-4.5%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: per_step_bias
# Steps: 3 | Iterations: 3
# Base theta_net params: 13
# Correction params: 3
# Total trainable: 16
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   per_step_bias       : pretrain=3.0123e-02 → finetune=3.0158e-02 (Δ=-0.1%, corr_params=3)
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: per_step_gate
# Steps: 3 | Iterations: 3
# ...

# %% [markdown]
# #### Burgers Equation

# %%
results = test_theta_param_modes(
    pde_type='burgers',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=1000,
    pretrain_lr=0.0005,
    finetune_lr=0.0001,
    n_data=50,
    noise_level=0.05,
    freeze_base=True
)

plot_correction_comparison(results, pde_type='burgers')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: burgers | Mode: none
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   phi_x, _ = quad(integrand_phi_x, limit_low, limit_high,
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=1.6236e-01 → finetune=1.7250e-01 (Δ=-6.2%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: burgers | Mode: per_step_bias
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# [ThetaParams] Corrections DISABLED
# ...

# %% [markdown]
# #### Reaction-Diffusion Equation

# %%
results = test_theta_param_modes(
            pde_type='reaction_diffusion',
            n_runs=5,
            pretrain_epochs=150,
            finetune_epochs=1000,
            pretrain_lr=0.005,
            finetune_lr=0.0001,
            n_data=50,
            noise_level=0.05,
            freeze_base=True
        )

plot_correction_comparison(results, pde_type='reaction_diffusion')
# Out:
# ...
# RUN 1/5 (seed=42)
# ...
#
# ...
# LF-PINN Theta Params
# PDE: reaction_diffusion | Mode: none
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 0
# Total trainable: 13
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: none)
# [ThetaParams] Correction params UNFROZEN
#   none                : pretrain=1.3583e-01 → finetune=1.3581e-01 (Δ=+0.0%, corr_params=0)
#
# ...
# LF-PINN Theta Params
# PDE: reaction_diffusion | Mode: per_step_bias
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   per_step_bias       : pretrain=1.3583e-01 → finetune=1.3552e-01 (Δ=+0.2%, corr_params=2)
#
# ...
# LF-PINN Theta Params
# ...
