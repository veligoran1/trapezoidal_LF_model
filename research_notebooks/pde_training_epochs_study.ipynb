# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import pde_training_l2re_study
from utils.plot_utils import plot_l2re_study

# %% [markdown]
# ## Epochs vs L2RE Error Test (No data)

# %% [markdown]
# ### Epochs vs L2RE Error Test - Heat Equation

# %%
results = pde_training_l2re_study(
            pde_type='heat',
            n_runs=5,
            max_epochs=500,
            eval_every=1,
            verbose=True
        )
        
plot_l2re_study(results)
# Out:
# ...
# PDE TRAINING L2RE STUDY: Heat Equation
# ...
# Runs: 5, Max epochs: 500, Eval every: 1
# LR: 0.005, n_collocation: 30
# ...
#
#
# Run 1/5
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: heat | Max Steps: 4 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.4
# ...
#
#   Epoch 0: L2RE=1.87e-02
#   Epoch 10: L2RE=1.86e-02, Loss=4.46e-03, θ=0.391
#   Epoch 20: L2RE=1.97e-02, Loss=4.25e-03, θ=0.382
#   Epoch 30: L2RE=1.91e-02, Loss=4.34e-03, θ=0.384
#   Epoch 40: L2RE=1.85e-02, Loss=5.99e-03, θ=0.391
#   Epoch 50: L2RE=1.87e-02, Loss=5.19e-03, θ=0.386
#   Epoch 60: L2RE=1.90e-02, Loss=3.47e-03, θ=0.384
#   Epoch 70: L2RE=1.86e-02, Loss=4.56e-03, θ=0.386
#   Epoch 80: L2RE=1.84e-02, Loss=4.79e-03, θ=0.385
#   Epoch 90: L2RE=1.94e-02, Loss=4.42e-03, θ=0.376
#   Epoch 100: L2RE=1.81e-02, Loss=4.33e-03, θ=0.381
#   Epoch 110: L2RE=1.73e-02, Loss=3.13e-03, θ=0.387
#   Epoch 120: L2RE=1.81e-02, Loss=2.99e-03, θ=0.373
#   Epoch 130: L2RE=1.80e-02, Loss=3.74e-03, θ=0.367
# ...

# %% [markdown]
# ### Epochs vs L2RE Error Test - Burgers Equation

# %%
results = pde_training_l2re_study(
            pde_type='burgers',
            n_runs=5,
            max_epochs=500,
            eval_every=1,
            verbose=True
        )
        
plot_l2re_study(results)
# Out:
# ...
# PDE TRAINING L2RE STUDY: Burgers Equation
# ...
# Runs: 5, Max epochs: 500, Eval every: 1
# LR: 0.0005, n_collocation: 30
# ...
#
#
# Run 1/5
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: burgers | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.0005
# Initial theta: 0.3
# ...
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   phi_x, _ = quad(integrand_phi_x, limit_low, limit_high,
#   Epoch 0: L2RE=1.69e-01
#   Epoch 10: L2RE=1.69e-01, Loss=1.16e+00, θ=0.294
#   Epoch 20: L2RE=1.68e-01, Loss=8.30e+00, θ=0.293
#   Epoch 30: L2RE=1.68e-01, Loss=3.07e+00, θ=0.291
#   Epoch 40: L2RE=1.68e-01, Loss=7.22e-01, θ=0.290
#   Epoch 50: L2RE=1.67e-01, Loss=5.55e+00, θ=0.288
#   Epoch 60: L2RE=1.67e-01, Loss=6.96e-01, θ=0.287
# ...

# %% [markdown]
# ### Epochs vs L2RE Error Test - Wave Equation

# %%
results = pde_training_l2re_study(
            pde_type='wave',
            n_runs=5,
            max_epochs=500,
            eval_every=1,
            verbose=True
        )
        
plot_l2re_study(results)
# Out:
# ...
# PDE TRAINING L2RE STUDY: Wave Equation
# ...
# Runs: 5, Max epochs: 500, Eval every: 1
# LR: 0.001, n_collocation: 30
# ...
#
#
# Run 1/5
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: wave | Max Steps: 3 | Params: 13
# Iterations: 3 | LR: 0.001
# Initial theta: 0.5
# ...
#
#   Epoch 0: L2RE=1.45e-01
#   Epoch 10: L2RE=1.34e-01, Loss=1.51e+00, θ=0.484
#   Epoch 20: L2RE=1.24e-01, Loss=1.50e+00, θ=0.478
#   Epoch 30: L2RE=1.13e-01, Loss=1.12e+00, θ=0.472
#   Epoch 40: L2RE=1.03e-01, Loss=6.19e-01, θ=0.467
#   Epoch 50: L2RE=9.22e-02, Loss=6.17e-01, θ=0.461
#   Epoch 60: L2RE=8.12e-02, Loss=3.78e-01, θ=0.455
#   Epoch 70: L2RE=7.01e-02, Loss=3.31e-01, θ=0.449
#   Epoch 80: L2RE=5.89e-02, Loss=4.26e-01, θ=0.442
#   Epoch 90: L2RE=4.82e-02, Loss=2.45e-01, θ=0.435
#   Epoch 100: L2RE=3.87e-02, Loss=6.52e-02, θ=0.428
#   Epoch 110: L2RE=3.20e-02, Loss=4.09e-02, θ=0.421
#   Epoch 120: L2RE=3.01e-02, Loss=4.18e-02, θ=0.415
#   Epoch 130: L2RE=3.02e-02, Loss=6.10e-02, θ=0.413
# ...

# %% [markdown]
# ### Epochs vs L2RE Error Test - Reaction-Diffusion Equation

# %%
results = pde_training_l2re_study(
            pde_type='reaction_diffusion',
            n_runs=5,
            max_epochs=500,
            eval_every=1,
            verbose=True
        )
        
plot_l2re_study(results)
# Out:
# ...
# PDE TRAINING L2RE STUDY: Reaction-Diffusion
# ...
# Runs: 5, Max epochs: 500, Eval every: 1
# LR: 0.005, n_collocation: 30
# ...
#
#
# Run 1/5
#
# ...
# Low-Fidelity PINN (Fixed-Point + Adaptive Steps)
# PDE: reaction_diffusion | Max Steps: 2 | Params: 13
# Iterations: 2 | LR: 0.005
# Initial theta: 0.3
# ...
#
#   Epoch 0: L2RE=1.36e-01
#   Epoch 10: L2RE=1.36e-01, Loss=3.56e-02, θ=0.286
#   Epoch 20: L2RE=1.36e-01, Loss=1.91e-02, θ=0.272
#   Epoch 30: L2RE=1.36e-01, Loss=1.98e-03, θ=0.258
#   Epoch 40: L2RE=1.36e-01, Loss=3.07e-05, θ=0.249
#   Epoch 50: L2RE=1.36e-01, Loss=8.65e-04, θ=0.241
#   Epoch 60: L2RE=1.36e-01, Loss=1.47e-04, θ=0.233
#   Epoch 70: L2RE=1.36e-01, Loss=1.58e-02, θ=0.228
#   Epoch 80: L2RE=1.36e-01, Loss=1.65e-03, θ=0.219
#   Epoch 90: L2RE=1.36e-01, Loss=7.57e-03, θ=0.210
#   Epoch 100: L2RE=1.36e-01, Loss=1.94e-04, θ=0.202
#   Epoch 110: L2RE=1.36e-01, Loss=5.34e-03, θ=0.194
#   Epoch 120: L2RE=1.36e-01, Loss=1.50e-03, θ=0.190
#   Epoch 130: L2RE=1.36e-01, Loss=5.27e-03, θ=0.183
# ...
