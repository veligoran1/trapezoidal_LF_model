# %%
cd ..
# Out:
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model
# /Users/igor.velikorechanin/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from utils.benchmark_utils import data_training_epochs_study
from utils.plot_utils import plot_data_tratining_epochs_study

# %% [markdown]
# ### Data Training Epochs Study - Heat Equation

# %%
results = data_training_epochs_study(
    'heat',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=3000,
    finetune_lr= 0.0005,
    eval_every=100,
    correction_mode='per_step_gate'
)

plot_data_tratining_epochs_study(results, 'Heat Equation')
# Out:
# ...
# EPOCHS SATURATION STUDY: HEAT | mode=per_step_gate
# ...
#
# Run 1/5
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_gate
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 8
# Total trainable: 21
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
#   Pretrain done: L2RE=1.23e-02
# [ThetaParams] Corrections ENABLED (mode: per_step_gate)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   Epoch 500: L2RE=8.68e-03, DataLoss=4.23e-05
#   Epoch 1000: L2RE=7.95e-03, DataLoss=4.18e-05
#   Epoch 1500: L2RE=7.79e-03, DataLoss=4.18e-05
#   Epoch 2000: L2RE=7.67e-03, DataLoss=4.17e-05
#   Epoch 2500: L2RE=7.53e-03, DataLoss=4.17e-05
#   Epoch 3000: L2RE=7.37e-03, DataLoss=4.16e-05
#
# Run 2/5
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_gate
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 8
# Total trainable: 21
# ...
#
# [ThetaParams] Corrections DISABLED
# ...

# %%
results = data_training_epochs_study(
    'heat',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=3000,
    finetune_lr= 0.002,
    eval_every=100,
    correction_mode='per_step_bias'
)

plot_data_tratining_epochs_study(results, 'Heat Equation')
# Out:
# ...
# EPOCHS SATURATION STUDY: HEAT | mode=per_step_bias
# ...
#
# Run 1/5
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_bias
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 4
# Total trainable: 17
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
#   Pretrain done: L2RE=1.23e-02
# [ThetaParams] Corrections ENABLED (mode: per_step_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   Epoch 500: L2RE=6.35e-03, DataLoss=4.15e-05
#   Epoch 1000: L2RE=6.15e-03, DataLoss=4.14e-05
#   Epoch 1500: L2RE=6.15e-03, DataLoss=4.14e-05
#   Epoch 2000: L2RE=6.15e-03, DataLoss=4.14e-05
#   Epoch 2500: L2RE=6.15e-03, DataLoss=4.14e-05
#   Epoch 3000: L2RE=6.15e-03, DataLoss=4.14e-05
#
# Run 2/5
#
# ...
# LF-PINN Theta Params
# PDE: heat | Mode: per_step_bias
# Steps: 4 | Iterations: 2
# Base theta_net params: 13
# Correction params: 4
# Total trainable: 17
# ...
#
# [ThetaParams] Corrections DISABLED
# ...

# %% [markdown]
# ### Data Training Epochs Study - Wave Equation

# %%
results = data_training_epochs_study(
    'wave',
    n_runs=5,
    pretrain_epochs=150,
    finetune_epochs=3000,
    finetune_lr=0.002,
    eval_every=100, 
    correction_mode='rhs_scale'
)

plot_data_tratining_epochs_study(results, 'Wave Equation')
# Out:
# ...
# EPOCHS SATURATION STUDY: WAVE | mode=rhs_scale
# ...
#
# Run 1/5
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: rhs_scale
# Steps: 3 | Iterations: 3
# Base theta_net params: 13
# Correction params: 3
# Total trainable: 16
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
#   Pretrain done: L2RE=3.11e-02
# [ThetaParams] Corrections ENABLED (mode: rhs_scale)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   Epoch 500: L2RE=1.49e-02, DataLoss=4.29e-04
#   Epoch 1000: L2RE=1.23e-02, DataLoss=3.99e-04
#   Epoch 1500: L2RE=1.43e-02, DataLoss=3.84e-04
#   Epoch 2000: L2RE=1.43e-02, DataLoss=3.84e-04
#   Epoch 2500: L2RE=1.43e-02, DataLoss=3.83e-04
#   Epoch 3000: L2RE=1.44e-02, DataLoss=3.83e-04
#
# Run 2/5
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: rhs_scale
# Steps: 3 | Iterations: 3
# Base theta_net params: 13
# Correction params: 3
# Total trainable: 16
# ...
#
# [ThetaParams] Corrections DISABLED
# ...

# %%
results = data_training_epochs_study(
    'wave',
    n_runs=5,
    pretrain_epochs=150,
    finetune_epochs=3000,
    finetune_lr=0.0001,
    eval_every=100, 
    correction_mode='time_gate+rhs_scale'
)

plot_data_tratining_epochs_study(results, 'Wave Equation')
# Out:
# ...
# EPOCHS SATURATION STUDY: WAVE | mode=time_gate+rhs_scale
# ...
#
# Run 1/5
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: time_gate+rhs_scale
# Steps: 3 | Iterations: 3
# Time anchors: 5 | t_max: 1.0
# Base theta_net params: 13
# Correction params: 13
# Total trainable: 26
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
#   Pretrain done: L2RE=3.11e-02
# [ThetaParams] Corrections ENABLED (mode: time_gate+rhs_scale)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   Epoch 500: L2RE=1.08e-02, DataLoss=3.88e-04
#   Epoch 1000: L2RE=1.09e-02, DataLoss=3.82e-04
#   Epoch 1500: L2RE=1.12e-02, DataLoss=3.78e-04
#   Epoch 2000: L2RE=1.17e-02, DataLoss=3.75e-04
#   Epoch 2500: L2RE=1.23e-02, DataLoss=3.73e-04
#   Epoch 3000: L2RE=1.29e-02, DataLoss=3.72e-04
#
# Run 2/5
#
# ...
# LF-PINN Theta Params
# PDE: wave | Mode: time_gate+rhs_scale
# Steps: 3 | Iterations: 3
# Time anchors: 5 | t_max: 1.0
# Base theta_net params: 13
# ...

# %% [markdown]
# ### Data Training Epochs Study - Burgers Equation

# %%
results = data_training_epochs_study(
    'burgers',
    n_runs=5,
    pretrain_epochs=200,
    finetune_epochs=3000,
    finetune_lr=0.0001,
    eval_every=100,
    correction_mode='rhs_scale'
)

plot_data_tratining_epochs_study(results, 'Burgers Equation')
# Out:
# ...
# EPOCHS SATURATION STUDY: BURGERS | mode=rhs_scale
# ...
#
# Run 1/5
#
# ...
# LF-PINN Theta Params
# PDE: burgers | Mode: rhs_scale
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
# /Users/igor.velikorechanin/Desktop/Masters/Thesis/GitHub PINN 4/trapezoidal_LF_model/utils/pde_utils.py:448: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   phi_x, _ = quad(integrand_phi_x, limit_low, limit_high,
#   Pretrain done: L2RE=1.64e-01
# [ThetaParams] Corrections ENABLED (mode: rhs_scale)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   Epoch 500: L2RE=1.42e-01, DataLoss=5.83e-03
#   Epoch 1000: L2RE=1.30e-01, DataLoss=4.97e-03
#   Epoch 1500: L2RE=1.24e-01, DataLoss=4.51e-03
# ...

# %% [markdown]
# ### Data Training Epochs Study - Reaction-Diffusion Equation

# %%
results = data_training_epochs_study(
    'reaction_diffusion',
    n_runs=5,
    pretrain_epochs=110,
    finetune_epochs=3000,
    finetune_lr=0.0001,
    eval_every=100,
    correction_mode='output_bias'
)

plot_data_tratining_epochs_study(results, 'Reaction-Diffusion Equation')
# Out:
# ...
# EPOCHS SATURATION STUDY: REACTION_DIFFUSION | mode=output_bias
# ...
#
# Run 1/5
#
# ...
# LF-PINN Theta Params
# PDE: reaction_diffusion | Mode: output_bias
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# [ThetaParams] Corrections DISABLED
# [ThetaParams] Correction params FROZEN
#   Pretrain done: L2RE=1.36e-01
# [ThetaParams] Corrections ENABLED (mode: output_bias)
# [ThetaParams] Correction params UNFROZEN
# [ThetaParams] Base theta_net FROZEN
#   Epoch 500: L2RE=1.26e-01, DataLoss=3.13e-03
#   Epoch 1000: L2RE=1.26e-01, DataLoss=3.12e-03
#   Epoch 1500: L2RE=1.26e-01, DataLoss=3.12e-03
#   Epoch 2000: L2RE=1.26e-01, DataLoss=3.11e-03
#   Epoch 2500: L2RE=1.26e-01, DataLoss=3.11e-03
#   Epoch 3000: L2RE=1.26e-01, DataLoss=3.11e-03
#
# Run 2/5
#
# ...
# LF-PINN Theta Params
# PDE: reaction_diffusion | Mode: output_bias
# Steps: 2 | Iterations: 2
# Base theta_net params: 13
# Correction params: 2
# Total trainable: 15
# ...
#
# ...
